# %%
import numpy as np
import pandas as pd
from collections import Counter

# %%
dados = pd.read_csv("date//MICRODADOS_ENEM_2019_sp.csv", sep=';', encoding='iso-8859-1')

# %%
dados.head()
# Out:
#   NU_INSCRICAO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0     1,90E+11                  3546801            Santa Isabel
# 1     1,90E+11                  3538204             Pinhalzinho
# 2     1,90E+11                  3550308               São Paulo
# 3     1,90E+11                  3548708   São Bernardo do Campo
# 4     1,90E+11                  3549409    São Joaquim da Barra
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                35               SP        22       M                1
# 1                35               SP        19       M                1
# 2                35               SP        17       F                1
# 3                35               SP        19       M                1
# 4                35               SP        37       M                2
#
#    TP_COR_RACA  TP_NACIONALIDADE  ...  NU_NOTA_MT TP_LINGUA  \
# 0            3                 1  ...      6002.0         0
# 1            3                 1  ...         NaN         1
# 2            3                 1  ...      7318.0         0
# 3            3                 1  ...      3932.0         1
# 4            1                 1  ...         NaN         1
#
#    TP_STATUS_REDACAO NU_NOTA_COMP1  NU_NOTA_COMP2  NU_NOTA_COMP3  \
# 0                1.0         160.0          200.0          180.0
# 1                NaN           NaN            NaN            NaN
# 2                1.0         160.0          120.0          200.0
# 3                1.0          80.0          160.0          120.0
# 4                NaN           NaN            NaN            NaN
#
#    NU_NOTA_COMP4  NU_NOTA_COMP5  NU_NOTA_REDACAO  Q025
# 0          200.0          200.0            940.0     B
# 1            NaN            NaN              NaN     A
# 2          200.0          200.0            880.0     A
# 3          100.0          100.0            560.0     B
# 4            NaN            NaN              NaN     B
#
# [5 rows x 44 columns]

# %%
dados.head()
# Out:
#   NU_INSCRICAO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0     1,90E+11                  3546801            Santa Isabel
# 1     1,90E+11                  3538204             Pinhalzinho
# 2     1,90E+11                  3550308               São Paulo
# 3     1,90E+11                  3548708   São Bernardo do Campo
# 4     1,90E+11                  3549409    São Joaquim da Barra
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                35               SP        22       M                1
# 1                35               SP        19       M                1
# 2                35               SP        17       F                1
# 3                35               SP        19       M                1
# 4                35               SP        37       M                2
#
#    TP_COR_RACA  TP_NACIONALIDADE  ...  NU_NOTA_MT TP_LINGUA  \
# 0            3                 1  ...      6002.0         0
# 1            3                 1  ...         NaN         1
# 2            3                 1  ...      7318.0         0
# 3            3                 1  ...      3932.0         1
# 4            1                 1  ...         NaN         1
#
#    TP_STATUS_REDACAO NU_NOTA_COMP1  NU_NOTA_COMP2  NU_NOTA_COMP3  \
# 0                1.0         160.0          200.0          180.0
# 1                NaN           NaN            NaN            NaN
# 2                1.0         160.0          120.0          200.0
# 3                1.0          80.0          160.0          120.0
# 4                NaN           NaN            NaN            NaN
#
#    NU_NOTA_COMP4  NU_NOTA_COMP5  NU_NOTA_REDACAO  Q025
# 0          200.0          200.0            940.0     B
# 1            NaN            NaN              NaN     A
# 2          200.0          200.0            880.0     A
# 3          100.0          100.0            560.0     B
# 4            NaN            NaN              NaN     B
#
# [5 rows x 44 columns]

# %%
dados.shape
# Out:
# (813772, 44)

# %%
dados.dtypes
# Out:
# NU_INSCRICAO                object
# CO_MUNICIPIO_RESIDENCIA      int64
# NO_MUNICIPIO_RESIDENCIA     object
# CO_UF_RESIDENCIA             int64
# SG_UF_RESIDENCIA            object
# NU_IDADE                     int64
# TP_SEXO                     object
# TP_ESTADO_CIVIL              int64
# TP_COR_RACA                  int64
# TP_NACIONALIDADE             int64
# CO_MUNICIPIO_NASCIMENTO    float64
# NO_MUNICIPIO_NASCIMENTO     object
# CO_UF_NASCIMENTO           float64
# SG_UF_NASCIMENTO            object
# TP_ST_CONCLUSAO              int64
# TP_ANO_CONCLUIU              int64
# TP_ESCOLA                    int64
# TP_ENSINO                  float64
# IN_TREINEIRO                 int64
# CO_ESCOLA                  float64
# CO_MUNICIPIO_ESC           float64
# NO_MUNICIPIO_ESC            object
# CO_UF_ESC                  float64
# SG_UF_ESC                   object
# TP_DEPENDENCIA_ADM_ESC     float64
# TP_LOCALIZACAO_ESC         float64
# TP_SIT_FUNC_ESC            float64
# TP_PRESENCA_CN               int64
# TP_PRESENCA_CH               int64
# TP_PRESENCA_LC               int64
# TP_PRESENCA_MT               int64
# NU_NOTA_CN                 float64
# NU_NOTA_CH                 float64
# NU_NOTA_LC                 float64
# NU_NOTA_MT                 float64
# TP_LINGUA                    int64
# TP_STATUS_REDACAO          float64
# NU_NOTA_COMP1              float64
# NU_NOTA_COMP2              float64
# NU_NOTA_COMP3              float64
# NU_NOTA_COMP4              float64
# NU_NOTA_COMP5              float64
# NU_NOTA_REDACAO            float64
# Q025                        object
# dtype: object

# %%
dados1 = dados.drop(columns=['CO_MUNICIPIO_RESIDENCIA'])
dados1.head()
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  \
# 0     1,90E+11            Santa Isabel                35               SP
# 1     1,90E+11             Pinhalzinho                35               SP
# 2     1,90E+11               São Paulo                35               SP
# 3     1,90E+11   São Bernardo do Campo                35               SP
# 4     1,90E+11    São Joaquim da Barra                35               SP
#
#    NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_NACIONALIDADE  \
# 0        22       M                1            3                 1
# 1        19       M                1            3                 1
# 2        17       F                1            3                 1
# 3        19       M                1            3                 1
# 4        37       M                2            1                 1
#
#    CO_MUNICIPIO_NASCIMENTO  ... NU_NOTA_MT  TP_LINGUA TP_STATUS_REDACAO  \
# 0                1506500.0  ...     6002.0          0               1.0
# 1                1503804.0  ...        NaN          1               NaN
# 2                1501402.0  ...     7318.0          0               1.0
# 3                3548708.0  ...     3932.0          1               1.0
# 4                3549409.0  ...        NaN          1               NaN
#
#    NU_NOTA_COMP1  NU_NOTA_COMP2  NU_NOTA_COMP3  NU_NOTA_COMP4  NU_NOTA_COMP5  \
# 0          160.0          200.0          180.0          200.0          200.0
# 1            NaN            NaN            NaN            NaN            NaN
# 2          160.0          120.0          200.0          200.0          200.0
# 3           80.0          160.0          120.0          100.0          100.0
# 4            NaN            NaN            NaN            NaN            NaN
#
#    NU_NOTA_REDACAO  Q025
# 0            940.0     B
# 1              NaN     A
# 2            880.0     A
# 3            560.0     B
# 4              NaN     B
#
# [5 rows x 43 columns]

# %%
dados1 = dados1.drop(columns=['CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA', 'CO_MUNICIPIO_NASCIMENTO'],)
dados1.head()
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0     1,90E+11            Santa Isabel        22       M                1
# 1     1,90E+11             Pinhalzinho        19       M                1
# 2     1,90E+11               São Paulo        17       F                1
# 3     1,90E+11   São Bernardo do Campo        19       M                1
# 4     1,90E+11    São Joaquim da Barra        37       M                2
#
#    TP_COR_RACA  TP_NACIONALIDADE NO_MUNICIPIO_NASCIMENTO  CO_UF_NASCIMENTO  \
# 0            3                 1    Santa Izabel do Pará              15.0
# 1            3                 1                 Jacundá              15.0
# 2            3                 1                   Belém              15.0
# 3            3                 1   São Bernardo do Campo              35.0
# 4            1                 1    São Joaquim da Barra              35.0
#
#   SG_UF_NASCIMENTO  ...  NU_NOTA_MT  TP_LINGUA  TP_STATUS_REDACAO  \
# 0               PA  ...      6002.0          0                1.0
# 1               PA  ...         NaN          1                NaN
# 2               PA  ...      7318.0          0                1.0
# 3               SP  ...      3932.0          1                1.0
# 4               SP  ...         NaN          1                NaN
#
#    NU_NOTA_COMP1  NU_NOTA_COMP2  NU_NOTA_COMP3  NU_NOTA_COMP4 NU_NOTA_COMP5  \
# 0          160.0          200.0          180.0          200.0         200.0
# 1            NaN            NaN            NaN            NaN           NaN
# 2          160.0          120.0          200.0          200.0         200.0
# 3           80.0          160.0          120.0          100.0         100.0
# 4            NaN            NaN            NaN            NaN           NaN
#
#    NU_NOTA_REDACAO Q025
# 0            940.0    B
# 1              NaN    A
# 2            880.0    A
# 3            560.0    B
# 4              NaN    B
#
# [5 rows x 40 columns]

# %%
dados1 = dados1.drop(columns=['NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
                              'TP_ANO_CONCLUIU', 'TP_ENSINO', 'CO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC'])

# %%
dados1.head()
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0     1,90E+11            Santa Isabel        22       M                1
# 1     1,90E+11             Pinhalzinho        19       M                1
# 2     1,90E+11               São Paulo        17       F                1
# 3     1,90E+11   São Bernardo do Campo        19       M                1
# 4     1,90E+11    São Joaquim da Barra        37       M                2
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ESCOLA  IN_TREINEIRO  \
# 0            3                 1                1          1             0
# 1            3                 1                1          1             0
# 2            3                 1                2          3             0
# 3            3                 1                2          2             0
# 4            1                 1                1          1             0
#
#    ...  NU_NOTA_MT TP_LINGUA  TP_STATUS_REDACAO  NU_NOTA_COMP1  NU_NOTA_COMP2  \
# 0  ...      6002.0         0                1.0          160.0          200.0
# 1  ...         NaN         1                NaN            NaN            NaN
# 2  ...      7318.0         0                1.0          160.0          120.0
# 3  ...      3932.0         1                1.0           80.0          160.0
# 4  ...         NaN         1                NaN            NaN            NaN
#
#    NU_NOTA_COMP3  NU_NOTA_COMP4  NU_NOTA_COMP5  NU_NOTA_REDACAO  Q025
# 0          180.0          200.0          200.0            940.0     B
# 1            NaN            NaN            NaN              NaN     A
# 2          200.0          200.0          200.0            880.0     A
# 3          120.0          100.0          100.0            560.0     B
# 4            NaN            NaN            NaN              NaN     B
#
# [5 rows x 32 columns]

# %%
dados1 = dados1.drop(columns=['TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC'], )
dados1.head()
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0     1,90E+11            Santa Isabel        22       M                1
# 1     1,90E+11             Pinhalzinho        19       M                1
# 2     1,90E+11               São Paulo        17       F                1
# 3     1,90E+11   São Bernardo do Campo        19       M                1
# 4     1,90E+11    São Joaquim da Barra        37       M                2
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ESCOLA  IN_TREINEIRO  \
# 0            3                 1                1          1             0
# 1            3                 1                1          1             0
# 2            3                 1                2          3             0
# 3            3                 1                2          2             0
# 4            1                 1                1          1             0
#
#    ...  NU_NOTA_MT TP_LINGUA  TP_STATUS_REDACAO  NU_NOTA_COMP1  NU_NOTA_COMP2  \
# 0  ...      6002.0         0                1.0          160.0          200.0
# 1  ...         NaN         1                NaN            NaN            NaN
# 2  ...      7318.0         0                1.0          160.0          120.0
# 3  ...      3932.0         1                1.0           80.0          160.0
# 4  ...         NaN         1                NaN            NaN            NaN
#
#    NU_NOTA_COMP3  NU_NOTA_COMP4  NU_NOTA_COMP5  NU_NOTA_REDACAO  Q025
# 0          180.0          200.0          200.0            940.0     B
# 1            NaN            NaN            NaN              NaN     A
# 2          200.0          200.0          200.0            880.0     A
# 3          120.0          100.0          100.0            560.0     B
# 4            NaN            NaN            NaN              NaN     B
#
# [5 rows x 29 columns]

# %%
dados1.shape
# Out:
# (813772, 29)

# %%
dados1.loc[:,'NU_NOTA_CN']/=10
dados1.loc[:,'NU_NOTA_MT']/=10
dados1.loc[:,'NU_NOTA_LC']/=10
dados1.loc[:,'NU_NOTA_CH']/=10
dados1.head(5)
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0     1,90E+11            Santa Isabel        22       M                1
# 1     1,90E+11             Pinhalzinho        19       M                1
# 2     1,90E+11               São Paulo        17       F                1
# 3     1,90E+11   São Bernardo do Campo        19       M                1
# 4     1,90E+11    São Joaquim da Barra        37       M                2
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ESCOLA  IN_TREINEIRO  \
# 0            3                 1                1          1             0
# 1            3                 1                1          1             0
# 2            3                 1                2          3             0
# 3            3                 1                2          2             0
# 4            1                 1                1          1             0
#
#    ...  NU_NOTA_MT TP_LINGUA  TP_STATUS_REDACAO  NU_NOTA_COMP1  NU_NOTA_COMP2  \
# 0  ...       600.2         0                1.0          160.0          200.0
# 1  ...         NaN         1                NaN            NaN            NaN
# 2  ...       731.8         0                1.0          160.0          120.0
# 3  ...       393.2         1                1.0           80.0          160.0
# 4  ...         NaN         1                NaN            NaN            NaN
#
#    NU_NOTA_COMP3  NU_NOTA_COMP4  NU_NOTA_COMP5  NU_NOTA_REDACAO  Q025
# 0          180.0          200.0          200.0            940.0     B
# 1            NaN            NaN            NaN              NaN     A
# 2          200.0          200.0          200.0            880.0     A
# 3          120.0          100.0          100.0            560.0     B
# 4            NaN            NaN            NaN              NaN     B
#
# [5 rows x 29 columns]

# %%
dados1 = dados1.rename(columns={'NU_NOTA_REDACAO': 'NOTA_REDACAO'})
dados1 = dados1.rename(columns={'NU_NOTA_CN': 'NOTA_CN', 'NU_NOTA_MT': 'NOTA_MT', 'NU_NOTA_CH': 'NOTA_CH', 'NU_NOTA_LC': 'NOTA_LC'})

# %%
dados1 = dados1.rename(columns={'NU_NOTA_COMP1': 'COMP1', 'NU_NOTA_COMP2': 'COMP2', 'NU_NOTA_COMP3' : 'COMP3', 'NU_NOTA_COMP4' : 'COMP4', 'NU_NOTA_COMP5' : 'COMP5'})
dados1 = dados1.rename(columns={'NU_IDADE': 'IDADE', 'TP_SEXO': 'SEXO', 'TP_COR_RACA': 'RACA',
                                'Q025': 'INTERNET', 'TP_ESCOLA': 'ESCOLA'})

# %%
dados1.head()
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL  RACA  \
# 0     1,90E+11            Santa Isabel     22    M                1     3
# 1     1,90E+11             Pinhalzinho     19    M                1     3
# 2     1,90E+11               São Paulo     17    F                1     3
# 3     1,90E+11   São Bernardo do Campo     19    M                1     3
# 4     1,90E+11    São Joaquim da Barra     37    M                2     1
#
#    TP_NACIONALIDADE  TP_ST_CONCLUSAO  ESCOLA  IN_TREINEIRO  ...  NOTA_MT  \
# 0                 1                1       1             0  ...    600.2
# 1                 1                1       1             0  ...      NaN
# 2                 1                2       3             0  ...    731.8
# 3                 1                2       2             0  ...    393.2
# 4                 1                1       1             0  ...      NaN
#
#   TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  \
# 0         0                1.0  160.0  200.0  180.0  200.0  200.0
# 1         1                NaN    NaN    NaN    NaN    NaN    NaN
# 2         0                1.0  160.0  120.0  200.0  200.0  200.0
# 3         1                1.0   80.0  160.0  120.0  100.0  100.0
# 4         1                NaN    NaN    NaN    NaN    NaN    NaN
#
#    NOTA_REDACAO  INTERNET
# 0         940.0         B
# 1           NaN         A
# 2         880.0         A
# 3         560.0         B
# 4           NaN         B
#
# [5 rows x 29 columns]

# %%
dados1['RACA'] = dados1['RACA'].replace({0:'não declarado', 1:'branca', 2:"preta", 3:"parda", 4: 'amarela', 5:'indigena'})

# %%
dados1['IDADE'].value_counts()
# Out:
# IDADE
# 17    219313
# 18    147548
# 19     81236
# 16     59316
# 20     53009
#        ...
# 91         1
# 4          1
# 3          1
# 86         1
# 2          1
# Name: count, Length: 80, dtype: int64

# %%
dados1['IDADE'].value_counts().sort_index()
# Out:
# IDADE
# 2     1
# 3     1
# 4     1
# 5     2
# 6     2
#      ..
# 80    2
# 81    3
# 82    2
# 86    1
# 91    1
# Name: count, Length: 80, dtype: int64

# %%
menores_12 = dados1.query('IDADE < 12')['NO_MUNICIPIO_RESIDENCIA'].value_counts()
menores_12
# Out:
# NO_MUNICIPIO_RESIDENCIA
# São Paulo                 5
# Tambaú                    1
# Ribeirão Preto            1
# Bálsamo                   1
# São Bernardo do Campo     1
# Embu das Artes            1
# Queiroz                   1
# Santana de Parnaíba       1
# Vargem Grande Paulista    1
# Auriflama                 1
# Araçatuba                 1
# Campinas                  1
# Name: count, dtype: int64

# %%
dados_maiores_11 = dados1.loc[dados1.IDADE >11]
dados_maiores_11
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL  \
# 0          1,90E+11            Santa Isabel     22    M                1
# 1          1,90E+11             Pinhalzinho     19    M                1
# 2          1,90E+11               São Paulo     17    F                1
# 3          1,90E+11   São Bernardo do Campo     19    M                1
# 4          1,90E+11    São Joaquim da Barra     37    M                2
# ...             ...                     ...    ...  ...              ...
# 813767     1,90E+11               São Paulo     17    F                1
# 813768     1,90E+11               São Paulo     17    F                1
# 813769     1,90E+11               São Paulo     17    M                1
# 813770     1,90E+11                 Cajamar     21    F                1
# 813771     1,90E+11                  Araras     18    F                1
#
#           RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  ESCOLA  IN_TREINEIRO  ...  \
# 0        parda                 1                1       1             0  ...
# 1        parda                 1                1       1             0  ...
# 2        parda                 1                2       3             0  ...
# 3        parda                 1                2       2             0  ...
# 4       branca                 1                1       1             0  ...
# ...        ...               ...              ...     ...           ...  ...
# 813767   preta                 1                2       2             0  ...
# 813768   parda                 1                2       2             0  ...
# 813769   parda                 1                2       2             0  ...
# 813770   parda                 1                1       1             0  ...
# 813771  branca                 1                2       2             0  ...
#
#         NOTA_MT TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  \
# 0         600.2         0                1.0  160.0  200.0  180.0  200.0
# 1           NaN         1                NaN    NaN    NaN    NaN    NaN
# 2         731.8         0                1.0  160.0  120.0  200.0  200.0
# 3         393.2         1                1.0   80.0  160.0  120.0  100.0
# 4           NaN         1                NaN    NaN    NaN    NaN    NaN
# ...         ...       ...                ...    ...    ...    ...    ...
# 813767     43.2         1                1.0   80.0  120.0  140.0  120.0
# 813768    487.3         0                1.0  120.0   80.0   60.0  120.0
# 813769    401.1         0                1.0  160.0  120.0  160.0  140.0
# 813770      NaN         1                NaN    NaN    NaN    NaN    NaN
# 813771    559.5         0                1.0  120.0  120.0  120.0  120.0
#
#         COMP5  NOTA_REDACAO  INTERNET
# 0       200.0         940.0         B
# 1         NaN           NaN         A
# 2       200.0         880.0         A
# 3       100.0         560.0         B
# 4         NaN           NaN         B
# ...       ...           ...       ...
# 813767  100.0         560.0         B
# 813768    0.0         380.0         B
# 813769  160.0         740.0         A
# 813770    NaN           NaN         B
# 813771  140.0         620.0         B
#
# [813756 rows x 29 columns]

# %%
dados_maiores_11['IDADE'].value_counts().sort_index()
# Out:
# IDADE
# 12        6
# 13       29
# 14      355
# 15    11583
# 16    59316
#       ...
# 80        2
# 81        3
# 82        2
# 86        1
# 91        1
# Name: count, Length: 73, dtype: int64

# %%
dados_maiores_11.query("IN_TREINEIRO == 1")['IN_TREINEIRO'].value_counts()
# Out:
# IN_TREINEIRO
# 1    93988
# Name: count, dtype: int64

# %%
treineiros = dados_maiores_11.loc[dados_maiores_11.IN_TREINEIRO ==1]
treineiros
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL  \
# 20         1,90E+11                  Santos     15    F                1
# 21         1,90E+11                Panorama     16    F                1
# 106        1,90E+11               São Paulo     16    F                1
# 109        1,90E+11        Águas de Lindóia     16    M                1
# 159        1,90E+11        Águas de Lindóia     15    M                1
# ...             ...                     ...    ...  ...              ...
# 813551     1,90E+11                    Iepê     16    M                0
# 813592     1,90E+11                 Barueri     17    F                1
# 813604     1,90E+11               São Paulo     16    F                1
# 813740     1,90E+11             Santo André     16    M                1
# 813741     1,90E+11     São José dos Campos     17    F                1
#
#           RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  ESCOLA  IN_TREINEIRO  ...  \
# 20       parda                 1                3       1             1  ...
# 21       parda                 1                3       1             1  ...
# 106     branca                 1                3       1             1  ...
# 109     branca                 1                3       1             1  ...
# 159     branca                 1                3       1             1  ...
# ...        ...               ...              ...     ...           ...  ...
# 813551  branca                 1                3       1             1  ...
# 813592   parda                 1                3       1             1  ...
# 813604  branca                 1                3       1             1  ...
# 813740  branca                 1                3       1             1  ...
# 813741   parda                 1                3       1             1  ...
#
#         NOTA_MT TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  \
# 20        573.2         0                1.0  140.0  120.0  120.0  100.0
# 21          NaN         1                NaN    NaN    NaN    NaN    NaN
# 106       532.6         0                1.0  120.0  120.0  120.0  100.0
# 109         NaN         1                NaN    NaN    NaN    NaN    NaN
# 159         NaN         0                NaN    NaN    NaN    NaN    NaN
# ...         ...       ...                ...    ...    ...    ...    ...
# 813551    415.7         0                1.0  160.0  120.0  140.0  120.0
# 813592      NaN         1                1.0  120.0  120.0  120.0  120.0
# 813604    525.4         0                1.0  140.0  180.0  160.0  160.0
# 813740    720.6         0                1.0  140.0  140.0  160.0  160.0
# 813741    689.2         0                1.0  140.0  120.0  160.0  160.0
#
#         COMP5  NOTA_REDACAO  INTERNET
# 20       80.0         560.0         B
# 21        NaN           NaN         A
# 106      80.0         540.0         B
# 109       NaN           NaN         B
# 159       NaN           NaN         B
# ...       ...           ...       ...
# 813551  140.0         680.0         B
# 813592  100.0         580.0         B
# 813604  180.0         820.0         B
# 813740  160.0         760.0         B
# 813741  160.0         740.0         B
#
# [93988 rows x 29 columns]

# %%
treineiros.to_csv('date//treineiros_enem_2019_sp.csv', encoding='iso-8859-1', index=False)

# %%
vestibulandos = dados_maiores_11.loc[dados_maiores_11.IN_TREINEIRO ==0]
vestibulandos
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL  \
# 0          1,90E+11            Santa Isabel     22    M                1
# 1          1,90E+11             Pinhalzinho     19    M                1
# 2          1,90E+11               São Paulo     17    F                1
# 3          1,90E+11   São Bernardo do Campo     19    M                1
# 4          1,90E+11    São Joaquim da Barra     37    M                2
# ...             ...                     ...    ...  ...              ...
# 813767     1,90E+11               São Paulo     17    F                1
# 813768     1,90E+11               São Paulo     17    F                1
# 813769     1,90E+11               São Paulo     17    M                1
# 813770     1,90E+11                 Cajamar     21    F                1
# 813771     1,90E+11                  Araras     18    F                1
#
#           RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  ESCOLA  IN_TREINEIRO  ...  \
# 0        parda                 1                1       1             0  ...
# 1        parda                 1                1       1             0  ...
# 2        parda                 1                2       3             0  ...
# 3        parda                 1                2       2             0  ...
# 4       branca                 1                1       1             0  ...
# ...        ...               ...              ...     ...           ...  ...
# 813767   preta                 1                2       2             0  ...
# 813768   parda                 1                2       2             0  ...
# 813769   parda                 1                2       2             0  ...
# 813770   parda                 1                1       1             0  ...
# 813771  branca                 1                2       2             0  ...
#
#         NOTA_MT TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  \
# 0         600.2         0                1.0  160.0  200.0  180.0  200.0
# 1           NaN         1                NaN    NaN    NaN    NaN    NaN
# 2         731.8         0                1.0  160.0  120.0  200.0  200.0
# 3         393.2         1                1.0   80.0  160.0  120.0  100.0
# 4           NaN         1                NaN    NaN    NaN    NaN    NaN
# ...         ...       ...                ...    ...    ...    ...    ...
# 813767     43.2         1                1.0   80.0  120.0  140.0  120.0
# 813768    487.3         0                1.0  120.0   80.0   60.0  120.0
# 813769    401.1         0                1.0  160.0  120.0  160.0  140.0
# 813770      NaN         1                NaN    NaN    NaN    NaN    NaN
# 813771    559.5         0                1.0  120.0  120.0  120.0  120.0
#
#         COMP5  NOTA_REDACAO  INTERNET
# 0       200.0         940.0         B
# 1         NaN           NaN         A
# 2       200.0         880.0         A
# 3       100.0         560.0         B
# 4         NaN           NaN         B
# ...       ...           ...       ...
# 813767  100.0         560.0         B
# 813768    0.0         380.0         B
# 813769  160.0         740.0         A
# 813770    NaN           NaN         B
# 813771  140.0         620.0         B
#
# [719768 rows x 29 columns]

# %%
vestibulandos.shape
# Out:
# (719768, 29)

# %%
vestibulandos.to_csv('date//vestibulandos_enem_2019_sp.csv', encoding='iso-8859-1', index=False)

# %%
vestibulandos['TP_PRESENCA_CN'].value_counts()
# Out:
# TP_PRESENCA_CN
# 1    500805
# 0    218693
# 2       270
# Name: count, dtype: int64

# %%
vestibulandos['TP_STATUS_REDACAO'].value_counts().sort_index()
# Out:
# TP_STATUS_REDACAO
# 1.0    519763
# 2.0       913
# 3.0      1417
# 4.0      5513
# 6.0      3626
# 7.0       543
# 8.0       828
# 9.0       539
# Name: count, dtype: int64

# %%
vestibulandos['IDADE'].isnull().sum()
# Out:
# np.int64(0)

# %%
presenca_total = ['TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_MT', 'TP_PRESENCA_LC']
presenca_total
# Out:
# ['TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_MT', 'TP_PRESENCA_LC']

# %%
provas = ['NOTA_REDACAO', 'NOTA_CN', 'NOTA_MT', 'NOTA_CH', 'NOTA_LC']
vestibulandos[provas].isnull().sum()
# Out:
# NOTA_REDACAO    186626
# NOTA_CN         218963
# NOTA_MT         218963
# NOTA_CH         186626
# NOTA_LC         186626
# dtype: int64
