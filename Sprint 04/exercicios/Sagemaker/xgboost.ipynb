# %%
import pandas as pd
import numpy as np 

base_casas = pd.read_csv('house_prices.csv')
base_casas
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
print(base_casas.columns)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
base_casas.drop(columns = ['id', 'date', 'sqft_living15', 'sqft_lot15'], axis=1,  inplace=True)
base_casas
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# 1               0     0          3      7        2170            400
# 2               0     0          3      6         770              0
# 3               0     0          5      7        1050            910
# 4               0     0          3      8        1680              0
# ...           ...   ...        ...    ...         ...            ...
# 21608           0     0          3      8        1530              0
# 21609           0     0          3      8        2310              0
# 21610           0     0          3      7        1020              0
# 21611           0     0          3      8        1600              0
# 21612           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode      lat     long
# 0          1955             0    98178  47.5112 -122.257
# 1          1951          1991    98125  47.7210 -122.319
# 2          1933             0    98028  47.7379 -122.233
# 3          1965             0    98136  47.5208 -122.393
# 4          1987             0    98074  47.6168 -122.045
# ...         ...           ...      ...      ...      ...
# 21608      2009             0    98103  47.6993 -122.346
# 21609      2014             0    98146  47.5107 -122.362
# 21610      2009             0    98144  47.5944 -122.299
# 21611      2004             0    98027  47.5345 -122.069
# 21612      2008             0    98144  47.5941 -122.299
#
# [21613 rows x 17 columns]

# %%
base_treinamento = base_casas.iloc[0:15129,:]

# %%
base_treinamento.shape
# Out:
# (15129, 17)

# %%
base_teste = base_casas.iloc[15129:,:]
base_teste.shape
# Out:
# (6484, 17)

# %%
X_teste = base_teste.iloc[:,1:17].values
X_teste
# Out:
# array([[ 4.00000e+00,  2.75000e+00,  2.58000e+03, ...,  9.81150e+04,
#          4.76753e+01, -1.22304e+02],
#        [ 4.00000e+00,  2.50000e+00,  3.20000e+03, ...,  9.80590e+04,
#          4.75273e+01, -1.22143e+02],
#        [ 3.00000e+00,  1.00000e+00,  8.40000e+02, ...,  9.81780e+04,
#          4.74940e+01, -1.22275e+02],
#        ...,
#        [ 2.00000e+00,  7.50000e-01,  1.02000e+03, ...,  9.81440e+04,
#          4.75944e+01, -1.22299e+02],
#        [ 3.00000e+00,  2.50000e+00,  1.60000e+03, ...,  9.80270e+04,
#          4.75345e+01, -1.22069e+02],
#        [ 2.00000e+00,  7.50000e-01,  1.02000e+03, ...,  9.81440e+04,
#          4.75941e+01, -1.22299e+02]])

# %%
y_teste = base_teste.iloc[:,0].values

# %%
y_teste
# Out:
# array([937750., 725126., 135000., ..., 402101., 400000., 325000.])

# %%
base_treinamento.to_csv('house_prices_train_xgboost.csv', header= False, index=False)
base_teste.to_csv('house_prices_test_xgboost.csv', header= False, index=False)

# %%
import sagemaker
import boto3
import os
from sagemaker import Session
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
session = sagemaker.Session()
bucket = 'curso-aws-sagemaker-1736262933'
subpasta_modelo = 'modelos/house-prices/xgboost'
subpasta_dataset = 'datasets/house-prices'
key_train = 'houses-train-data-xgboost'
key_test = 'houses-test-data-xgboost'
role = sagemaker.get_execution_role()
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, subpasta_dataset, key_train)
s3_test_data = 's3://{}/{}/test/{}'.format(bucket, subpasta_dataset, key_test)
output_location ='s3://{}/{}/output'.format(bucket, subpasta_modelo)
print(role)
print(s3_train_data)
print(s3_test_data)
print(output_location)
# Out:
# arn:aws:iam::879381239590:role/service-role/AmazonSageMaker-ExecutionRole-20250103T092221
# s3://curso-aws-sagemaker-1736262933/datasets/house-prices/train/houses-train-data-xgboost
# s3://curso-aws-sagemaker-1736262933/datasets/house-prices/test/houses-test-data-xgboost
# s3://curso-aws-sagemaker-1736262933/modelos/house-prices/xgboost/output

# %%
with open('house_prices_train_xgboost.csv', 'rb') as f:
    boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(subpasta_dataset, 'train', key_train)).upload_fileobj(f)

# %%
with open('house_prices_test_xgboost.csv', 'rb') as f:
    boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(subpasta_dataset, 'test', key_test)).upload_fileobj(f)

# %%
from sagemaker import image_uris
contianer = image_uris.retrieve(framework = 'xgboost', region = boto3.Session().region_name, version= 'latest')

# %%
xgboost = sagemaker.estimator.Estimator(image_uri = contianer,
                                        role = role, 
                                        instance_count =1, 
                                        instance_type = 'ml.m5.large',
                                        outpu_path = output_location,
                                        sagemaker_session = session)

# %%
xgboost.set_hyperparameters(num_round = 100)

# %%
train_input = sagemaker.inputs.TrainingInput(s3_data= s3_train_data, content_type='csv', s3_data_type='S3Prefix')
validation_input = sagemaker.inputs.TrainingInput(s3_data= s3_test_data, content_type='csv', s3_data_type='S3Prefix')
data_channels = {'train': train_input, 'validation': validation_input}

# %%
xgboost.fit(data_channels)
# Out:
# INFO:sagemaker:Creating training-job with name: xgboost-2025-01-09-02-33-10-581
# 2025-01-09 02:33:12 Starting - Starting the training job...
# 2025-01-09 02:33:26 Starting - Preparing the instances for training...
# 2025-01-09 02:33:53 Downloading - Downloading input data...
# 2025-01-09 02:34:38 Downloading - Downloading the training image...
# 2025-01-09 02:35:14 Training - Training image download completed. Training in progress..Arguments: train
# [2025-01-09:02:35:17:INFO] Running standalone xgboost training.
# [2025-01-09:02:35:17:INFO] File size need to be processed in the node: 1.55mb. Available memory size in the node: 159.59mb
# [2025-01-09:02:35:17:INFO] Determined delimiter of CSV input is ','
# [02:35:17] S3DistributionType set as FullyReplicated
# [02:35:17] 15129x16 matrix with 242064 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2025-01-09:02:35:17:INFO] Determined delimiter of CSV input is ','
# [02:35:17] S3DistributionType set as FullyReplicated
# [02:35:17] 6484x16 matrix with 103744 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [02:35:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [0]#011train-rmse:470556#011validation-rmse:488482
# [02:35:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-rmse:349103#011validation-rmse:364995
# [02:35:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-rmse:265763#011validation-rmse:282964
# [02:35:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-rmse:209380#011validation-rmse:226980
# [02:35:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-rmse:172422#011validation-rmse:193026
# [02:35:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-rmse:147947#011validation-rmse:171920
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-rmse:131343#011validation-rmse:157350
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=6
# [7]#011train-rmse:120283#011validation-rmse:146962
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-rmse:112496#011validation-rmse:141205
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-rmse:108028#011validation-rmse:138073
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-rmse:105103#011validation-rmse:136574
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [11]#011train-rmse:102048#011validation-rmse:134824
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [12]#011train-rmse:99098.8#011validation-rmse:132881
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [13]#011train-rmse:97927.4#011validation-rmse:132125
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-rmse:96913.1#011validation-rmse:131518
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-rmse:95556.1#011validation-rmse:130557
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-rmse:94358.5#011validation-rmse:129864
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-rmse:93512.8#011validation-rmse:129672
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [18]#011train-rmse:92368.3#011validation-rmse:128961
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=6
# [19]#011train-rmse:90808.5#011validation-rmse:128654
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [20]#011train-rmse:89538.9#011validation-rmse:127921
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [21]#011train-rmse:88515.9#011validation-rmse:127360
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [22]#011train-rmse:87664.5#011validation-rmse:126847
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-rmse:87071.3#011validation-rmse:126698
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [24]#011train-rmse:86183.8#011validation-rmse:126479
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [25]#011train-rmse:85441.1#011validation-rmse:126310
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [26]#011train-rmse:84229.6#011validation-rmse:125711
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [27]#011train-rmse:83479.3#011validation-rmse:125483
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [28]#011train-rmse:82456.5#011validation-rmse:125393
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [29]#011train-rmse:81683.3#011validation-rmse:125239
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [30]#011train-rmse:81335.5#011validation-rmse:125331
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [31]#011train-rmse:80743.9#011validation-rmse:125246
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [32]#011train-rmse:80146.9#011validation-rmse:125307
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [33]#011train-rmse:79583.6#011validation-rmse:125052
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [34]#011train-rmse:79181.8#011validation-rmse:125064
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [35]#011train-rmse:78374.3#011validation-rmse:124741
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [36]#011train-rmse:77748#011validation-rmse:124442
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [37]#011train-rmse:77099.8#011validation-rmse:124443
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [38]#011train-rmse:76743.7#011validation-rmse:124197
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [39]#011train-rmse:76634.7#011validation-rmse:124100
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [40]#011train-rmse:76182.6#011validation-rmse:124080
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [41]#011train-rmse:75441.3#011validation-rmse:123983
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [42]#011train-rmse:75150.2#011validation-rmse:123894
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [43]#011train-rmse:74767.2#011validation-rmse:123636
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [44]#011train-rmse:74356.1#011validation-rmse:123569
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [45]#011train-rmse:73580.7#011validation-rmse:123155
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [46]#011train-rmse:72813.1#011validation-rmse:123242
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [47]#011train-rmse:72346.4#011validation-rmse:123385
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=6
# [48]#011train-rmse:71708.4#011validation-rmse:123489
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [49]#011train-rmse:71377.2#011validation-rmse:123387
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [50]#011train-rmse:71003#011validation-rmse:123322
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [51]#011train-rmse:70255.8#011validation-rmse:123163
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [52]#011train-rmse:69727.2#011validation-rmse:123042
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [53]#011train-rmse:69440.7#011validation-rmse:123111
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [54]#011train-rmse:68825.1#011validation-rmse:123141
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [55]#011train-rmse:68565.3#011validation-rmse:123090
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [56]#011train-rmse:68338.4#011validation-rmse:123152
# [02:35:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [57]#011train-rmse:67920.7#011validation-rmse:123112
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [58]#011train-rmse:67691.5#011validation-rmse:123068
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [59]#011train-rmse:67354.8#011validation-rmse:123099
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [60]#011train-rmse:67214.5#011validation-rmse:123082
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [61]#011train-rmse:66841.3#011validation-rmse:123000
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [62]#011train-rmse:66220.1#011validation-rmse:122741
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [63]#011train-rmse:65776.9#011validation-rmse:122745
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=6
# [64]#011train-rmse:65230#011validation-rmse:122510
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [65]#011train-rmse:64952.9#011validation-rmse:122614
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [66]#011train-rmse:64498.1#011validation-rmse:122433
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [67]#011train-rmse:64177.6#011validation-rmse:122545
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [68]#011train-rmse:63860.8#011validation-rmse:122529
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [69]#011train-rmse:63643.2#011validation-rmse:122515
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [70]#011train-rmse:63290.7#011validation-rmse:122466
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [71]#011train-rmse:62927.3#011validation-rmse:122467
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [72]#011train-rmse:62666.3#011validation-rmse:122420
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [73]#011train-rmse:62308.9#011validation-rmse:122362
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [74]#011train-rmse:62192.3#011validation-rmse:122376
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [75]#011train-rmse:62037.5#011validation-rmse:122359
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [76]#011train-rmse:61797.9#011validation-rmse:122453
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=6
# [77]#011train-rmse:61252.2#011validation-rmse:122482
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [78]#011train-rmse:60662.8#011validation-rmse:122460
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [79]#011train-rmse:60478.4#011validation-rmse:122408
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=6
# [80]#011train-rmse:60104.5#011validation-rmse:122487
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [81]#011train-rmse:60042.5#011validation-rmse:122457
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [82]#011train-rmse:59856.7#011validation-rmse:122461
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [83]#011train-rmse:59576.2#011validation-rmse:122424
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [84]#011train-rmse:59223.4#011validation-rmse:122388
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [85]#011train-rmse:58942.1#011validation-rmse:122293
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [86]#011train-rmse:58657.7#011validation-rmse:122211
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [87]#011train-rmse:58411.9#011validation-rmse:122234
# [88]#011train-rmse:58308.5#011validation-rmse:122246
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [89]#011train-rmse:58279.1#011validation-rmse:122253
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [90]#011train-rmse:58107.2#011validation-rmse:122232
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [91]#011train-rmse:57885.6#011validation-rmse:122227
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [92]#011train-rmse:57525.8#011validation-rmse:122237
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [93]#011train-rmse:57313.3#011validation-rmse:122250
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [94]#011train-rmse:56991.2#011validation-rmse:122280
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [95]#011train-rmse:56903.8#011validation-rmse:122292
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [96]#011train-rmse:56724.3#011validation-rmse:122300
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [97]#011train-rmse:56407.2#011validation-rmse:122112
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [98]#011train-rmse:56064.4#011validation-rmse:122013
# [02:35:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [99]#011train-rmse:55896.7#011validation-rmse:121962
#
# 2025-01-09 02:35:38 Uploading - Uploading generated training model
# 2025-01-09 02:35:38 Completed - Training job completed
# Training seconds: 105
# Billable seconds: 105

# %%
xgboost_regressor = xgboost.deploy(initial_instance_count = 1, instance_type = 'ml.m5.large')
# Out:
# INFO:sagemaker:Creating model with name: xgboost-2025-01-09-02-35-58-196
# INFO:sagemaker:Creating endpoint-config with name xgboost-2025-01-09-02-35-58-196
# INFO:sagemaker:Creating endpoint with name xgboost-2025-01-09-02-35-58-196
# -----!

# %%
from sagemaker.serializers import CSVSerializer
xgboost_regressor.serializer = CSVSerializer()

# %%
print(X_teste.shape)
# Out:
# (6484, 16)

# %%
previsoes = np.array(xgboost_regressor.predict(X_teste).decode
                     ('utf-8').split(','))
previsoes
# Out:
# array(['715760.25', '759194.25', '125879.6640625', ..., '298663.34375',
#        '468468.5625', '292532.90625'], dtype='<U14')

# %%
previsoes.shape, y_teste.shape
# Out:
# ((6484,), (6484,))

# %%
import boto3

# Criar cliente do SageMaker
client = boto3.client('sagemaker', region_name='us-east-1')

# Listar os endpoints
response = client.list_endpoints()

# Exibir os endpoints
for endpoint in response['Endpoints']:
    print(endpoint['EndpointName'])
# Out:
# xgboost-2025-01-09-02-35-58-196

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
y_teste = pd.to_numeric(y_teste, errors='coerce')
previsoes = pd.to_numeric(previsoes, errors='coerce')
mae = mean_absolute_error(y_teste, previsoes)
mse = mean_squared_error(y_teste, previsoes)
print(mae, mse)
# Out:
# 69311.54741358536 14874845482.575417

# %%
# https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost_hyperparameters.html
tuning_job_config = {
    "ParameterRanges": {
      "CategoricalParameterRanges": [],
      "ContinuousParameterRanges": [
        {
          "MaxValue": "1",
          "MinValue": "0",
          "Name": "eta"
        },
        {
          "MaxValue": "2",
          "MinValue": "0",
          "Name": "alpha"
        },
        {
          "MaxValue": "10",
          "MinValue": "1",
          "Name": "min_child_weight"
        }
      ],
      "IntegerParameterRanges": [
        {
          "MaxValue": "10",
          "MinValue": "1",
          "Name": "max_depth"
        }
      ],
      "IntegerParameterRanges": [
        {
          "MaxValue": "300",
          "MinValue": "50",
          "Name": "num_round"
        }
      ]
    },
    "ResourceLimits": {
      "MaxNumberOfTrainingJobs": 9,
      "MaxParallelTrainingJobs": 3
    },
    "Strategy": "Bayesian",
    "HyperParameterTuningJobObjective": {
      "MetricName": "validation:error",
      "Type": "Minimize"
    }
  }

# %%
training_job_definition = {
    "AlgorithmSpecification": {
      "TrainingImage": container,
      "TrainingInputMode": "File"
    },
    "InputDataConfig": [
      {
        "ChannelName": "train",
        "CompressionType": "None",
        "ContentType": "csv",
        "DataSource": {
          "S3DataSource": {
            "S3DataDistributionType": "FullyReplicated",
            "S3DataType": "S3Prefix",
            "S3Uri": s3_train_data
          }
        }
      },
      {
        "ChannelName": "validation",
        "CompressionType": "None",
        "ContentType": "csv",
        "DataSource": {
          "S3DataSource": {
            "S3DataDistributionType": "FullyReplicated",
            "S3DataType": "S3Prefix",
            "S3Uri": s3_test_data
          }
        }
      }
    ],
    "OutputDataConfig": {
      "S3OutputPath": "s3://{}/{}/output".format(bucket,subpasta_modelo)
    },
    "ResourceConfig": {
      "InstanceCount": 1,
      "InstanceType": "ml.c4.2xlarge",
      "VolumeSizeInGB": 5
    },
    "RoleArn": role,
    "StaticHyperParameters": {
      "eval_metric": "error",
      "objective": "binary:logistic",
      "rate_drop": "0.3",
      "tweedie_variance_power": "1.4"
    },
    "StoppingCondition": {
      "MaxRuntimeInSeconds": 43200
    }
}

# %%
smclient = boto3.client('sagemaker')
smclient.create_hyper_parameter_tuning_job(HyperParameterTuningJobName = "xgboosttuningcensus",
                                          HyperParameterTuningJobConfig = tuning_job_config,
                                          TrainingJobDefinition = training_job_definition)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[44], line 2
#       1 smclient = boto3.client('sagemaker')
# ----> 2 smclient.create_hyper_parameter_tuning_job(HyperParameterTuningJobName = "xgboosttuningcensus",
#       3                                           HyperParameterTuningJobConfig = tuning_job_config,
#       4                                           TrainingJobDefinition = training_job_definition)
#
# File /opt/conda/lib/python3.11/site-packages/botocore/client.py:565, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     561     raise TypeError(
#     562         f"{py_operation_name}() only accepts keyword arguments."
#     563     )
#     564 # The "self" in this scope is referring to the BaseClient.
# --> 565 return self._make_api_call(operation_name, kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/botocore/client.py:1017, in BaseClient._make_api_call(self, operation_name, api_params)
#    1013     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1014         "Code"
#    1015     )
#    1016     error_class = self.exceptions.from_code(error_code)
# -> 1017     raise error_class(parsed_response, operation_name)
#    1018 else:
#    1019     return parsed_response
#
# ClientError: An error occurred (AccessDeniedException) when calling the CreateHyperParameterTuningJob operation: User: arn:aws:sts::879381239590:assumed-role/AmazonSageMaker-ExecutionRole-20250103T092221/SageMaker is not authorized to perform: sagemaker:CreateHyperParameterTuningJob on resource: arn:aws:sagemaker:us-east-1:879381239590:hyper-parameter-tuning-job/xgboosttuningcensus with an explicit deny in a service control policy
